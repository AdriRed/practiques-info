# %% [markdown]
# # Test Informàtica: camí a triar
# ### Sara Giménez Aragón

# %% [markdown]
# ### Primera Part

# %%
import random

def tria_cami():
    tria_OK = False #inicialitzem a False perquè entri sempre en el bucle
    while tria_OK == False:
        x = int(input("Quin camí vols agafar, 1 o 2?: "))
        if x < 1 or x > 2: print("Error!")
        else: tria_OK = True
        
    return x


def camrandom():
    x = random.randint(1,2)
    return x

def explorar_cami(a,b):
    if a == b: print("Per tu el tresor!!")
    else: print("Has estat devorat!!")



c = tria_cami()
print (c)
cr = camrandom()
print(cr)

ec = explorar_cami(c,cr)

final_partida = True #inicialitzem a True perquè entri sempre en el bucle
while final_partida == True:
    x = input("Vols tornar a jugar? ")
    if x == "No" or x == "no": 
        print ("Joc acabat!")
        final_partida = False
    else: 
        c = tria_cami()
        print (c)
        cr = camrandom()
        print(cr)

        ec = explorar_cami(c,cr)

# %% [markdown]
# >Per l'execució de la **primera part**, primerament he importat la llibreria `random`. He creat una funció perquè demani a l'usuari quin camí vol agafar. Per aasegurar que el valor que decideixi l'usuari sigui correcte (entre 1 o 2), he creat una variable inicialitzada a `False` i he establert que entri en el bucle sempre que aquesta sigui falsa (sempre entrarà en el bucle). Seguidament he fet un `input` per demanar número de camí a l'usuari. Amb la sentència `if` m'he assegurat que la x (el camí que escull l'usuari) estigui entre 1 i 2; en cas que no sigui així s'imprimirà per panatalla "Error!" i tornarà a entrar al bucle. Si pel contrari, la x és correcte (és o 1 o 2) la variable inventada serà `True` i així sortirem del bucle.
#
# > Per crear un número random entre 1 i 2 he utilitzat la funció `random.randint` i he especificat que el mínim sigui 1 i el màxim 2. S'executa correctament perquè he importat la llibreria `random` prèviament.
#
# >A continuació, he creat una funció que hem compara dos valors, establint el que vull que m'imprimeixi en cas que aquests siguin iguals o diferents.
#
# >Finalment, per l'última part, en el programa he fet un `input` (aquests ja són `strings`) per demanar si es vol tornar a jugar. En cas que l'usuari digui que no s'imprimirà un "Joc acabat!". Si l'usuari escriu qualsevol altra cosa (`else`), el joc es tronarà a executar.

# %% [markdown]
# ### Segona part

# %%
import random

def tria_cami():
    tria_OK = False #inicialitzem a False perquè entri sempre en el bucle
    while tria_OK == False:
        x = int(input("Quin camí vols agafar, 1 o 2?: "))
        if x < 1 or x > 2: print("Error!")
        else: tria_OK = True
        
    return x


def camrandom():
    x = random.randint(1,2)
    return x

def explorar_cami(a,b):
    if a == b: print("Per tu el tresor!!")
    else: print("Has estat devorat!!")



cont = 0 #inicialitzem el contador a 0

x = int(input("Quantes partides vols jugar? "))
y = tria_cami()

llista_T = []
llista_D = []

for i in range(1,x+1):    #el bucle arriba fins a x+1 perquè sinó no agafaria x
    cr = camrandom()
    ec = explorar_cami(y,cr)
    
    if y == cr:
        cont += 1
        llista_T = cont
    #else: 
        #llista_D = x - llista_T #em surt error perquè hauria de convertir la llista en un string
        
print("Nombre de vegades que has guanyat: ",llista_T)
print("Nombre de vegades que has perdut: ", llista_D)

p = (llista_T)*100/x
print("El teu percentatge de partides guanyades és del: ",(p))

# %% [markdown]
# > A l'hora de fer la **segona part** he començat per definir la variable `x`, la qual demana a l'usuari el nombre de vegades que vol jugar. Dins del bucle he exucutat el joc, establint que el bucle es farà (s'executarà el joc) `x+1` cops, ja que `x` són les vegades que l'usuari vol jugar i li he sumat 1 perquè el bucle `for i in range` no agafa l'últim nombre. A més a més, abans d'entrar en el bucle, he anomenat `y` a la funció `tria_cami()` perquè ara, l'usuari jugarà sempre amb el mateix camí.
#
# > Per guardar en una llista els cops guanyats i els cops perduts, he creat dues llistes (`llista_T` i `llista_D`), primer buides. Previ al bucle he definit un contador i l'he inicialitzat a 0. Dins del bucle he establert la condició que si (`if`) `y == cr` , és a dir, si el camí de l'usuari i el random són iguals, que puji el contador i m'inclogui aquest número en la `llista_T`. En cas contrari, s'afegirà a la `llista_D` la diferència del nombre de partides menys l'element de la `llista_T`. Aquestes llistes s'imprimiran per pantalla.
#
# > Finalment, per calcular el percentatge de jugades guanyades he definit `p` i he esbrinat el càlcul que s'ha de fer per obtenir el percentatge: cal multiplicar per 100 el nombre que conté la `llista_T` i dividir pel nombre de jugades (`x`).
# Aquest percentatge s'imprimirà per pantalla.
#
# > A sota es mostren les partides per a **20** i **100** jugades:

# %%
import random

def tria_cami():
    tria_OK = False #inicialitzem a False perquè entri sempre en el bucle
    while tria_OK == False:
        x = int(input("Quin camí vols agafar, 1 o 2?: "))
        if x < 1 or x > 2: print("Error!")
        else: tria_OK = True
        
    return x


def camrandom():
    x = random.randint(1,2)
    return x

def explorar_cami(a,b):
    if a == b: print("Per tu el tresor!!")
    else: print("Has estat devorat!!")



cont = 0 #inicialitzem el contador a 0

x = int(input("Quantes partides vols jugar? "))
y = tria_cami()

llista_T = []
llista_D = []

for i in range(1,x+1):    #el bucle arriba fins a x+1 perquè sinó no agafaria x
    cr = camrandom()
    ec = explorar_cami(y,cr)
    
    if y == cr:
        cont += 1
        llista_T = cont
    #else: 
        #llista_D = x - llista_T #em surt error perquè hauria de convertir la llista en un string
        
print("Nombre de vegades que has guanyat: ",llista_T)
print("Nombre de vegades que has perdut: ", llista_D)

p = (llista_T)*100/x
print("El teu percentatge de partides guanyades és del: ",(p))

# %%
import random

def tria_cami():
    tria_OK = False #inicialitzem a False perquè entri sempre en el bucle
    while tria_OK == False:
        x = int(input("Quin camí vols agafar, 1 o 2?: "))
        if x < 1 or x > 2: print("Error!")
        else: tria_OK = True
        
    return x


def camrandom():
    x = random.randint(1,2)
    return x

def explorar_cami(a,b):
    if a == b: print("Per tu el tresor!!")
    else: print("Has estat devorat!!")



cont = 0 #inicialitzem el contador a 0

x = int(input("Quantes partides vols jugar? "))
y = tria_cami()

llista_T = []
llista_D = []

for i in range(1,x+1):    #el bucle arriba fins a x+1 perquè sinó no agafaria x
    cr = camrandom()
    ec = explorar_cami(y,cr)
    
    if y == cr:
        cont += 1
        llista_T = cont
    #else: 
        #llista_D = x - llista_T      #em surt error perquè hauria de convertir la llista en un string
        
print("Nombre de vegades que has guanyat: ",llista_T)
print("Nombre de vegades que has perdut: ", llista_D)

p = (llista_T)*100/x
print("El teu percentatge de partides guanyades és del: ",(p))

# %%
import random

def tria_cami():
    tria_OK = False #inicialitzem a False perquè entri sempre en el bucle
    while tria_OK == False:
        x = int(input("Quin camí vols agafar, 1 o 2?: "))
        if x < 1 or x > 2: print("Error!")
        else: tria_OK = True
        
    return x


def camrandom():
    x = random.randint(1,2)
    return x

def explorar_cami(a,b):
    if a == b: print("Per tu el tresor!!")
    else: print("Has estat devorat!!")




x = int(input("Quantes partides vols jugar? "))
y = tria_cami()

llista_T = [0]
llista_D = [0]

for i in range(1,x+1):    #el bucle arriba fins a x+1 perquè sinó no agafaria x
    cr = camrandom()
    ec = explorar_cami(y,cr)
    
    if y == cr:
        llista_T[0]  += 1
    else: 
        cont_D += 1
        llista_D[0] += 1      #em surt error perquè hauria de convertir la llista en un string
        
print("Nombre de vegades que has guanyat: ",llista_T[0])
print("Nombre de vegades que has perdut: ", llista_D[0])

p = (llista_T[0])*100/x
print("El teu percentatge de partides guanyades és del: ",(p))
